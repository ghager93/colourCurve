# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

from colour import rgb2hsl, hsl2rgb

# %%
im = np.array(Image.open('lib/images/4xmr5mpelir51.jpg'))

# %%
plt.imshow(im)
print(im.shape)
# Out:
# (540, 960, 3)

# %%
im_hsl = np.array(rgb2hsl(*im.transpose(2, 0, 1)))
im_hsl.shape
# Out:
# (3, 540, 960)

# %%
print(np.max(im_hsl), np.min(im_hsl))

im_hsln = np.copy(im_hsl)
im_hsln[0] = im_hsln[0] / 360

print(np.max(im_hsln), np.min(im_hsln))
# Out:
# 359.7235023041475 0.0
# 1.0000000000000009 0.0

# %%
plt.imshow(im_hsln.transpose(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
im_rgb = hsl2rgb(im_hsl[0], im_hsl[1], 0.5)
im_rgb.shape
# Out:
# (540, 960, 3)

# %%
plt.imshow(im_rgb)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
