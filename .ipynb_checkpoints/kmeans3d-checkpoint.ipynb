# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
from sklearn.cluster import KMeans, MiniBatchKMeans
from random import sample
from sklearn.decomposition import PCA

from colour import *

# %%
im = np.array(Image.open('lib/images/okmJuRN.jpg'))
print(im.shape)
plt.imshow(im)
# Out:
# (2160, 3840, 3)

# %%
sample_mask = np.random.choice([False, True], (im.shape[0], im.shape[1]), p=[0.999, 0.001])
s_im = im[sample_mask].transpose()
s_im.shape
# Out:
# (3, 8315)

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s_im[0], s_im[1], s_im[2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
k_means = KMeans().fit(s_im.transpose())

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s_im[0], s_im[1], s_im[2], c=k_means.labels_)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
inertia_list = []
for i in range(1, 21):
    k_means = KMeans(n_clusters=i).fit(s_im.transpose())
    inertia_list.append(k_means.inertia_)
    
print(inertia_list)
# Out:
# [37527726.77306082, 23139746.642930508, 11479164.767093997, 8540520.294140518, 7094788.936469293, 5826947.405172666, 4994839.162926686, 4384436.413166889, 3986328.335236819, 3652586.277019165, 3387343.504511347, 3127295.305730769, 2954500.03456618, 2781310.98411119, 2637762.535984081, 2492477.434587055, 2374430.0227462575, 2254289.701900169, 2155858.1013775985, 2072934.7777394867]

# %%
plt.figure()
plt.plot(inertia_list)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s_im_hsl = np.array(rgb2hsl(*s_im))
s_im_hsl.shape
# Out:
# (3, 8315)

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s_im_hsl[0], s_im_hsl[1], s_im_hsl[2], c=k_means.labels_)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
k_means = KMeans().fit(s_im_hsl.transpose())

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s_im_hsl[0], s_im_hsl[1], s_im_hsl[2], c=k_means.labels_)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
inertia_list = []
for i in range(1, 21):
    k_means = KMeans(n_clusters=i).fit(s_im_hsl.transpose())
    inertia_list.append(k_means.inertia_)
    
print(inertia_list)
# Out:
# [719.3025066538855, 358.8878146460949, 238.9895180470186, 137.25893136087785, 108.08605038996504, 91.43882888758128, 80.1217524714559, 71.19432467665236, 63.55331978335242, 57.38987353149197, 52.12469930478578, 49.03144826585707, 45.825037286145296, 43.23018705652999, 40.688989115561675, 38.5475984225806, 36.90224652158028, 35.44020979043487, 33.857297658051166, 32.63284026332945]

# %%
plt.figure()
plt.plot(inertia_list)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
k_means = KMeans().fit(s_im_hsl.transpose())
centres = k_means.cluster_centers_
centres
# Out:
# array([[0.20663764, 0.17754625, 0.56569888],
#        [0.04104333, 0.57431814, 0.51776658],
#        [0.4526768 , 0.27930981, 0.48983861],
#        [0.94637372, 0.81557246, 0.30991804],
#        [0.11423944, 0.26618862, 0.5308119 ],
#        [0.56921359, 0.43699736, 0.3951966 ],
#        [0.11698524, 0.37920006, 0.63094463],
#        [0.98070484, 0.54266458, 0.44263332]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(*centres.transpose())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pca = PCA().fit(centres)
print(pca.components_)
print(pca.singular_values_)
# Out:
# [[ 0.90639459  0.36453537 -0.21345446]
#  [-0.39203175  0.91409969 -0.10359954]
#  [ 0.15735296  0.17758299  0.97144445]]
# [1.08218936 0.41193791 0.13158065]

# %%
origin = np.repeat(np.mean(centres, axis=0)[:, None], 3, axis=1)
vectors = (np.sqrt(pca.singular_values_) * pca.components_.transpose())
vectors
# Out:
# array([[ 0.94290716, -0.25161534,  0.05707829],
#        [ 0.37922006,  0.58669103,  0.06441654],
#        [-0.22205311, -0.06649266,  0.35238222]])

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.quiver(*origin, *vectors, color='red', length=0.5)
ax.scatter(*centres.transpose())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.repeat(np.mean(centres, axis=0)[:, None], 3, axis=1)
# Out:
# array([[0.42848432, 0.42848432, 0.42848432],
#        [0.43397466, 0.43397466, 0.43397466],
#        [0.48535107, 0.48535107, 0.48535107]])
